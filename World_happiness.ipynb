# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv(r"C:\Users\WINDOWS\Desktop\Python\2015.csv")
df = pd.read_csv(r"C:\Users\WINDOWS\Desktop\Python\2015.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head(50)
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe               1
# 1                Iceland                   Western Europe               2
# 2                Denmark                   Western Europe               3
# 3                 Norway                   Western Europe               4
# 4                 Canada                    North America               5
# 5                Finland                   Western Europe               6
# 6            Netherlands                   Western Europe               7
# 7                 Sweden                   Western Europe               8
# 8            New Zealand        Australia and New Zealand               9
# 9              Australia        Australia and New Zealand              10
# 10                Israel  Middle East and Northern Africa              11
# 11            Costa Rica      Latin America and Caribbean              12
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ##### Happiness Score Distribution

# %%
plt.figure(figsize=(24, 6))
sns.boxplot(y=df["Happiness Score"], x=df["Country"], showfliers=False)
plt.xticks(rotation=90)
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.title("Happiness Score Distribution by Country")
plt.show()

# %% [markdown]
# ##### Country with Highest Happiness Score

# %%
Country_with_highest_happiness_score= happiest_country = df.loc[df["Happiness Score"].idxmax(), "Country"]
highest_happiness_score = df["Happiness Score"].max()
print(f"Country with the Highest Happiness Score is {happiest_country} ({highest_happiness_score})")
# Out:
# Country with the Highest Happiness Score is Switzerland (7.587)

# %% [markdown]
# ##### Correlation between GDP per Capital and Happiness Score

# %%
correlation = df["Economy (GDP per Capita)"].corr(df["Happiness Score"])
print(f"Correlation between GDP per Capita and Happiness Score is {correlation:.2f}")
# Out:
# Correlation between GDP per Capita and Happiness Score is 0.78

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Economy (GDP per Capita)"], y=df["Happiness Score"])
plt.xlabel("GDP per Capita")
plt.ylabel("Happiness Score")
plt.title("GDP per Capita vs Happiness Score")
plt.show()

# %% [markdown]
# ##### What is the distribution of the factors that contribute to happiness?

# %%
factors = ["Economy (GDP per Capita)", "Family", "Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)", "Generosity"]
df[factors].hist(bins=20, figsize=(12, 8), edgecolor='black')
plt.suptitle("Distribution of Factors Contributing to Happiness")
plt.show()

# %% [markdown]
# ##### Which region of the world has the highest average happiness score?

# %%
region_avg_happiness = df.groupby("Region")["Happiness Score"].mean()
happiest_region = region_avg_happiness.idxmax()
highest_avg_score = region_avg_happiness.max()
print(f"Region with the Highest Average Happiness Score is {happiest_region} with ({highest_avg_score:.2f})")
# Out:
# Region with the Highest Average Happiness Score is Australia and New Zealand with (7.29)

# %%
print(type(region_avg_happiness))
print(region_avg_happiness.head())
# Out:
# <class 'pandas.core.series.Series'>
# Region
# Australia and New Zealand          7.285000
# Central and Eastern Europe         5.332931
# Eastern Asia                       5.626167
# Latin America and Caribbean        6.144682
# Middle East and Northern Africa    5.406900
# Name: Happiness Score, dtype: float64

# %%
region_avg_happiness = region_avg_happiness.to_frame().reset_index()
print(type(region_avg_happiness))
print(region_avg_happiness.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                             Region  Happiness Score
# 0        Australia and New Zealand         7.285000
# 1       Central and Eastern Europe         5.332931
# 2                     Eastern Asia         5.626167
# 3      Latin America and Caribbean         6.144682
# 4  Middle East and Northern Africa         5.406900

# %%
plt.figure(figsize=(24, 12))
sns.barplot(data= region_avg_happiness, x="Happiness Score", y="Region", palette="viridis")
plt.xlabel("Average Happiness Score")
plt.ylabel("Region")
plt.title("Average Happiness Score by Region")
plt.show()
# Out:
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_8184\393270191.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= region_avg_happiness, x="Happiness Score", y="Region", palette="viridis")

# %%
pd.read_csv(r"C:\Users\WINDOWS\Desktop\Python\worldhappiness2018.csv")
df2 = pd.read_csv(r"C:\Users\WINDOWS\Desktop\Python\worldhappiness2018.csv")
df2
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df2.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
df2["Perceptions of corruption"].fillna(df2["Perceptions of corruption"].mean() ,inplace=True)
# Out:
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_8184\4069696087.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Perceptions of corruption"].fillna(df2["Perceptions of corruption"].mean() ,inplace=True)

# %%
df2.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
# 5             6       Netherlands  7.441           1.361           1.488
# 6             7            Canada  7.328           1.330           1.532
# 7             8       New Zealand  7.324           1.268           1.601
# 8             9            Sweden  7.314           1.355           1.501
# 9            10         Australia  7.272           1.340           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# ...

# %%
df2.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df2.shape
# Out:
# (156, 9)

# %% [markdown]
# ##### What is the distribution of the happiness scores for each country?

# %%
plt.figure(figsize=(24, 6))
sns.boxplot(y=df2["Score"], x=df2["Country or region"], showfliers=False)
plt.xticks(rotation=90)
plt.xlabel("Country or Region")
plt.ylabel("Happiness Score")
plt.title("Happiness Score Distribution by Country")
plt.show()

# %% [markdown]
# ##### Which country has the highest happiness score?

# %%
Happiest_country = df2.loc[df2["Score"].idxmax(), "Country or region"]
Highest_happiness_score = df2["Score"].max()
print(f"The country that has the Highest Happiness score is {Happiest_country} with {Highest_happiness_score:.2f} Happiness Score")
# Out:
# The country that has the Highest Happiness score is Finland with 7.63 Happiness Score

# %% [markdown]
# ##### What is the correlation between GDP per capita and happiness score?

# %%
correlation = df2["GDP per capita"].corr(df2["Score"])
print(f"Correlation between GDP per Capita and Happiness Score is {correlation:.2%}")
# Out:
# Correlation between GDP per Capita and Happiness Score is 80.21%

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df2["GDP per capita"], y=df2["Score"])
plt.xlabel("GDP per capita")
plt.ylabel("Happiness Score")
plt.title("GDP per Capita vs Happiness Score")
plt.show()

# %% [markdown]
# ##### What is the distribution of the factors that contribute to happiness?

# %%
def plot_factor_distributions(df2):
words = ["GDP per capita", "Social support", "Healthy life expectancy", "Generosity", "Perceptions of corruption"]
plt.figure(figsize=(12, 8))
for word in words:
        plt.figure(figsize=(8, 4))
        sns.histplot(df2[word], bins=20, kde=True)
        plt.xlabel(word)
        plt.ylabel("Frequency")
        plt.title(f"Distribution of {word}")
        plt.show()
# Out:
#   Cell In[271], line 2
#     words = ["GDP per capita", "Social support", "Healthy life expectancy", "Generosity", "Perceptions of corruption"]
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ##### Which region of the world has the highest average happiness score?

# %%
region_avg_happiness2 = df2.groupby("Country or region")["Score"].mean()
happiest_region2 = region_avg_happiness2.idxmax()
highest_avg_score2 = region_avg_happiness2.max()
print(f"Region with the Highest Average Happiness Score is {happiest_region2} with {highest_avg_score2:.2f}")
# Out:
# Region with the Highest Average Happiness Score is Finland with 7.63

# %%
region_avg_happiness2 = region_avg_happiness2.to_frame().reset_index()

# %%
plt.figure(figsize=(6, 32))
sns.barplot(data= region_avg_happiness2, x="Score", y="Country or region", palette="viridis")
plt.xlabel("Average Happiness Score")
plt.ylabel("Region")
plt.title("Average Happiness Score by Region")
plt.show()
# Out:
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_8184\638180595.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= region_avg_happiness2, x="Score", y="Country or region", palette="viridis")
